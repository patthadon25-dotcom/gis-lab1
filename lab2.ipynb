# %% [markdown]
# # Following Tutorial

# %%
import folium 
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
provhall_loc = pd.read_csv('provhall_loc.csv')
provhall_loc.head()
